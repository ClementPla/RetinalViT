# %%
import kornia as K
import matplotlib.pyplot as plt
import torch

# %%
x = torch.arange(0, 128**2).reshape(1, 1, 128, 128).float()

indices = torch.zeros_like(x)
cp_1 = 32
cp_2 = 100
indices[:, :, cp_1-8:cp_1+8:, cp_1-8:cp_1+8] = 1
indices[:, :, cp_2-8:cp_2+8:, cp_2-8:cp_2+8] = 2

plt.imshow(indices[0, 0])
plt.show()

# %%
# Out:
# tensor(4000)
